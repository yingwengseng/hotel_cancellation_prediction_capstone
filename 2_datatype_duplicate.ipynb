# %% [markdown]
# # Capstone Part Two - Data Cleaning

# %% [markdown]
# ## Checking all Data types are in order and ensure no duplicates

# %%
import pandas as pd
import numpy as np

# %%
combinedhotel_df = pd.read_csv('combinedhotel.csv')

# %%
print(f"the dataset has {combinedhotel_df.shape[0]} rows and {combinedhotel_df.shape[1]} columns")
# Out:
# the dataset has 118902 rows and 32 columns

# %%
combinedhotel_df.head()
# Out:
#           hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0  resort hotel           0       342             2015             July
# 1  resort hotel           0       737             2015             July
# 2  resort hotel           0         7             2015             July
# 3  resort hotel           0        13             2015             July
# 4  resort hotel           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  ...      DepositType     Agent      Company  \
# 0                  0       2  ...  No Deposit       No Agent  Not Company
# 1                  0       2  ...  No Deposit       No Agent  Not Company
# 2                  1       1  ...  No Deposit       No Agent  Not Company
# 3                  1       1  ...  No Deposit            304  Not Company
# 4                  2       2  ...  No Deposit            240  Not Company
#
#   DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient   0.0                         0
# 1                 0    Transient   0.0                         0
# 2                 0    Transient  75.0                         0
# 3                 0    Transient  75.0                         0
# 4                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests  ReservationStatus ReservationStatusDate
# 0                       0          Check-Out            01/07/2015
# 1                       0          Check-Out            01/07/2015
# 2                       0          Check-Out            02/07/2015
# 3                       0          Check-Out            02/07/2015
# 4                       1          Check-Out            03/07/2015
#
# [5 rows x 32 columns]

# %% [markdown]
# Confirming that dataset has no nulls

# %%
combinedhotel_df.isnull().sum()
# Out:
# hotel                          0
# IsCanceled                     0
# LeadTime                       0
# ArrivalDateYear                0
# ArrivalDateMonth               0
# ArrivalDateWeekNumber          0
# ArrivalDateDayOfMonth          0
# StaysInWeekendNights           0
# StaysInWeekNights              0
# Adults                         0
# Children                       0
# Babies                         0
# Meal                           0
# Country                        0
# MarketSegment                  0
# DistributionChannel            0
# IsRepeatedGuest                0
# PreviousCancellations          0
# PreviousBookingsNotCanceled    0
# ReservedRoomType               0
# AssignedRoomType               0
# BookingChanges                 0
# DepositType                    0
# Agent                          0
# Company                        0
# DaysInWaitingList              0
# CustomerType                   0
# ADR                            0
# RequiredCarParkingSpaces       0
# TotalOfSpecialRequests         0
# ReservationStatus              0
# ReservationStatusDate          0
# dtype: int64

# %% [markdown]
# ## Datatype checks

# %% [markdown]
# identifying boolean columns

# %%
binary_columns = ['IsCanceled', 'IsRepeatedGuest']

# %% [markdown]
# casting boolean columns as boolean

# %%
combinedhotel_df[binary_columns] = combinedhotel_df[binary_columns].astype(bool)

# %%
combinedhotel_df[binary_columns].dtypes
# Out:
# IsCanceled         bool
# IsRepeatedGuest    bool
# dtype: object

# %%
numerical_columns = ['LeadTime', 'StaysInWeekendNights','StaysInWeekNights','Adults','Children',
                   'Babies','PreviousCancellations','PreviousBookingsNotCanceled', 'BookingChanges',
                   'DaysInWaitingList','ADR','RequiredCarParkingSpaces','TotalOfSpecialRequests']

# %%
combinedhotel_df[numerical_columns].dtypes
# Out:
# LeadTime                         int64
# StaysInWeekendNights             int64
# StaysInWeekNights                int64
# Adults                           int64
# Children                         int64
# Babies                           int64
# PreviousCancellations            int64
# PreviousBookingsNotCanceled      int64
# BookingChanges                   int64
# DaysInWaitingList                int64
# ADR                            float64
# RequiredCarParkingSpaces         int64
# TotalOfSpecialRequests           int64
# dtype: object

# %% [markdown]
# Casting datetime columns as datetime

# %%
combinedhotel_df.columns
# Out:
# Index(['hotel', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
categorical_columns = ['Meal', 'Country', 'MarketSegment', 'DistributionChannel',
                       'ReservedRoomType', 'AssignedRoomType','DepositType', 'Agent', 'Company',
                       'CustomerType','ReservationStatus']

# %%
combinedhotel_df[categorical_columns].dtypes
# Out:
# Meal                   object
# Country                object
# MarketSegment          object
# DistributionChannel    object
# ReservedRoomType       object
# AssignedRoomType       object
# DepositType            object
# Agent                  object
# Company                object
# CustomerType           object
# ReservationStatus      object
# dtype: object

# %%
date_not_datetime_columns = ['ArrivalDateYear','ArrivalDateMonth','ArrivalDateWeekNumber','ArrivalDateDayOfMonth']

# %%
combinedhotel_df[date_not_datetime_columns].dtypes
# Out:
# ArrivalDateYear           int64
# ArrivalDateMonth         object
# ArrivalDateWeekNumber     int64
# ArrivalDateDayOfMonth     int64
# dtype: object

# %%
combinedhotel_df.dtypes
# Out:
# hotel                           object
# IsCanceled                        bool
# LeadTime                         int64
# ArrivalDateYear                  int64
# ArrivalDateMonth                object
# ArrivalDateWeekNumber            int64
# ArrivalDateDayOfMonth            int64
# StaysInWeekendNights             int64
# StaysInWeekNights                int64
# Adults                           int64
# Children                         int64
# Babies                           int64
# Meal                            object
# Country                         object
# MarketSegment                   object
# DistributionChannel             object
# IsRepeatedGuest                   bool
# PreviousCancellations            int64
# PreviousBookingsNotCanceled      int64
# ReservedRoomType                object
# AssignedRoomType                object
# BookingChanges                   int64
# DepositType                     object
# Agent                           object
# Company                         object
# DaysInWaitingList                int64
# CustomerType                    object
# ADR                            float64
# RequiredCarParkingSpaces         int64
# TotalOfSpecialRequests           int64
# ReservationStatus               object
# ReservationStatusDate           object
# dtype: object

# %% [markdown]
# New 'ArrivalDate' column to capture full date

# %%
combinedhotel_df['ArrivalDate']= pd.to_datetime(
    combinedhotel_df['ArrivalDateDayOfMonth'].astype(str) + '/' +
    combinedhotel_df['ArrivalDateMonth'].astype(str) + '/' +
    combinedhotel_df['ArrivalDateYear'].astype(str),
    format='%d/%B/%Y'
)

# %%
datetime_columns = ['ReservationStatusDate','ArrivalDate']

# %%
combinedhotel_df['ReservationStatusDate'] = pd.to_datetime(combinedhotel_df['ReservationStatusDate'], format='%d/%m/%Y')

# %% [markdown]
# Inspecting data types

# %%
combinedhotel_df.dtypes
# Out:
# hotel                                  object
# IsCanceled                               bool
# LeadTime                                int64
# ArrivalDateYear                         int64
# ArrivalDateMonth                       object
# ArrivalDateWeekNumber                   int64
# ArrivalDateDayOfMonth                   int64
# StaysInWeekendNights                    int64
# StaysInWeekNights                       int64
# Adults                                  int64
# Children                                int64
# Babies                                  int64
# Meal                                   object
# Country                                object
# MarketSegment                          object
# DistributionChannel                    object
# IsRepeatedGuest                          bool
# PreviousCancellations                   int64
# PreviousBookingsNotCanceled             int64
# ReservedRoomType                       object
# AssignedRoomType                       object
# BookingChanges                          int64
# DepositType                            object
# Agent                                  object
# Company                                object
# DaysInWaitingList                       int64
# CustomerType                           object
# ADR                                   float64
# RequiredCarParkingSpaces                int64
# TotalOfSpecialRequests                  int64
# ReservationStatus                      object
# ReservationStatusDate          datetime64[ns]
# ArrivalDate                    datetime64[ns]
# dtype: object

# %%
# rearranging columns for target feature 'IsCanceld' to be the last column
combinedhotel_df = combinedhotel_df[[col for col in combinedhotel_df.columns if col != 'IsCanceled']+['IsCanceled']]

# %%
# inspect dataframe 
combinedhotel_df.sample(5)
# Out:
#               hotel  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 6393   resort hotel        58             2016             June
# 42796    city hotel        56             2015        September
# 94542    city hotel       180             2016           August
# 66420    city hotel       156             2017            April
# 46248    city hotel         9             2016          January
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 6393                      24                      7                     2
# 42796                     38                     17                     0
# 94542                     33                     10                     0
# 66420                     17                     26                     0
# 46248                      4                     17                     2
#
#        StaysInWeekNights  Adults  Children  ...      Company  \
# 6393                   8       2         0  ...  Not Company
# 42796                  2       2         0  ...  Not Company
# 94542                  4       3         0  ...  Not Company
# 66420                  3       2         0  ...  Not Company
# 46248                  0       2         0  ...  Not Company
#
#       DaysInWaitingList     CustomerType     ADR RequiredCarParkingSpaces  \
# 6393                  0        Transient  119.00                        0
# 42796                 0  Transient-Party   82.00                        0
# 94542                 0        Transient  130.05                        0
# 66420                 0        Transient  100.00                        0
# 46248                 0        Transient   77.25                        0
#
#        TotalOfSpecialRequests  ReservationStatus  ReservationStatusDate  \
# 6393                        0           Canceled             2016-04-10
# 42796                       0          Check-Out             2015-09-19
# 94542                       1          Check-Out             2016-08-14
# 66420                       0           Canceled             2016-11-21
# 46248                       0           Canceled             2016-01-14
#
#       ArrivalDate IsCanceled
# 6393   2016-06-07       True
# 42796  2015-09-17      False
# 94542  2016-08-10      False
# 66420  2017-04-26       True
# 46248  2016-01-17       True
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Checking for Duplication

# %%
# check number of duplicated rows
print (f' there are {combinedhotel_df.duplicated().sum()} duplicated rows')
# Out:
#  there are 31958 duplicated rows

# %%
combinedhotel_df[combinedhotel_df.duplicated()]['IsCanceled'].value_counts()
# Out:
# IsCanceled
# True     20166
# False    11792
# Name: count, dtype: int64

# %%
combinedhotel_df.IsCanceled.value_counts()
# Out:
# IsCanceled
# False    74745
# True     44157
# Name: count, dtype: int64

# %%
combinedhotel_df.columns
# Out:
# Index(['hotel', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate',
#        'ArrivalDate', 'IsCanceled'],
#       dtype='object')

# %%
# checking sample of duplicated rows

combinedhotel_df[combinedhotel_df.duplicated()].sample(5)
# Out:
#                hotel  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 6266    resort hotel       102             2016              May
# 32418   resort hotel        36             2017         February
# 88911     city hotel       198             2016              May
# 55459     city hotel       412             2016           August
# 112500    city hotel        11             2017              May
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 6266                       23                     31                     2
# 32418                       5                      4                     2
# 88911                      21                     20                     0
# 55459                      35                     25                     0
# 112500                     22                     29                     1
#
#         StaysInWeekNights  Adults  Children  ...      Company  \
# 6266                    5       2         0  ...  Not Company
# 32418                   2       2         0  ...  Not Company
# 88911                   1       2         0  ...  Not Company
# 55459                   2       2         0  ...  Not Company
# 112500                  2       1         0  ...  Not Company
#
#        DaysInWaitingList     CustomerType    ADR RequiredCarParkingSpaces  \
# 6266                   0        Transient   80.0                        0
# 32418                  0  Transient-Party   39.6                        0
# 88911                 98  Transient-Party   65.0                        0
# 55459                  0        Transient   62.0                        0
# 112500                 0        Transient  125.0                        0
#
#         TotalOfSpecialRequests  ReservationStatus  ReservationStatusDate  \
# 6266                         0           Canceled             2016-04-14
# 32418                        3          Check-Out             2017-02-08
# 88911                        0          Check-Out             2016-05-21
# 55459                        0           Canceled             2015-10-21
# 112500                       0          Check-Out             2017-06-01
#
#        ArrivalDate IsCanceled
# 6266    2016-05-31       True
# 32418   2017-02-04      False
# 88911   2016-05-20      False
# 55459   2016-08-25       True
# 112500  2017-05-29      False
#
# [5 rows x 33 columns]

# %% [markdown]
# Because the dataset does not have booking ID, unable to check if those are really duplicates or just multiple just multiple similar booking patterns from different customers due to customer mistakes.
# Hence final conclusion to drop duplicates to avoid affecting the analysis quality

# %%
# remove duplicates
combhotel_clean_df = combinedhotel_df.drop_duplicates()

# %% [markdown]
# Final checks on the clean dataframe before performing exploratory data analysis

# %%
# rows and columns overview
combhotel_clean_df.shape
# Out:
# (86944, 33)

# %%
# check for nulls
nullcheck = combhotel_clean_df.isnull().sum()
print(nullcheck[nullcheck>0])
# Out:
# Series([], dtype: int64)

# %%
# data type checks
combhotel_clean_df.dtypes
# Out:
# hotel                                  object
# LeadTime                                int64
# ArrivalDateYear                         int64
# ArrivalDateMonth                       object
# ArrivalDateWeekNumber                   int64
# ArrivalDateDayOfMonth                   int64
# StaysInWeekendNights                    int64
# StaysInWeekNights                       int64
# Adults                                  int64
# Children                                int64
# Babies                                  int64
# Meal                                   object
# Country                                object
# MarketSegment                          object
# DistributionChannel                    object
# IsRepeatedGuest                          bool
# PreviousCancellations                   int64
# PreviousBookingsNotCanceled             int64
# ReservedRoomType                       object
# AssignedRoomType                       object
# BookingChanges                          int64
# DepositType                            object
# Agent                                  object
# Company                                object
# DaysInWaitingList                       int64
# CustomerType                           object
# ADR                                   float64
# RequiredCarParkingSpaces                int64
# TotalOfSpecialRequests                  int64
# ReservationStatus                      object
# ReservationStatusDate          datetime64[ns]
# ArrivalDate                    datetime64[ns]
# IsCanceled                               bool
# dtype: object

# %%
# final check for duplicates
combhotel_clean_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
combhotel_clean_df.to_csv('combhotel_clean_df.csv', index=False)
